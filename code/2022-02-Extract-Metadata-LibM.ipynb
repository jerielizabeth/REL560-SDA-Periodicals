# %%
sources_dir = "/Users/jacobbarrett/Documents/GitHub/REL560-SDA-Periodicals/Periodicals/LibM"

# %%
sources_dir
# Out:
# '/Users/jacobbarrett/Documents/GitHub/REL560-SDA-Periodicals/Periodicals/LibM'

# %%
import os

# %%
os.listdir(sources_dir)
# Out:
# ['LibM19090401-V04-02.pdf',
#  'LibM19091001-V04-04.pdf',
#  'LibM19100701-V05-03.pdf',
#  'LibM19200701-V14-03.pdf',
#  'LibM19080101-V03-01.pdf',
#  'LibM19190701-V15-03.pdf',
#  'LibM19131001-V08-04.pdf',
#  'LibM19130401-V08-02.pdf',
#  'LibM19060701-V01-02.pdf',
#  'LibM19171001-V12-04.pdf',
#  'LibM19170401-V12-02.pdf',
#  'LibM19190101-V15-01.pdf',
#  'LibM19080701-V03-03.pdf',
#  'LibM19200101-V14-01.pdf',
#  'LibM19100101-V05-01.pdf',
#  'LibM19160401-V11-02e.pdf',
#  'LibM19160101-V11-01.pdf',
#  'LibM19120701-V07-03.pdf',
#  'LibM19140701-V09-03.pdf',
#  'LibM19160101-V11-01e.pdf',
#  'LibM19180101-V13-01.pdf',
#  'LibM19110401-V06-02.pdf',
#  'LibM19111001-V06-04.pdf',
#  'LibM19140101-V09-01.pdf',
#  'LibM19150401-V10-02.pdf',
#  'LibM19151001-V10-04.pdf',
#  'LibM19180701-V13-03.pdf',
#  'LibM19070401-V02-02.pdf',
#  'LibM19071001-V02-04.pdf',
#  'LibM19120101-V07-01.pdf',
#  'LibM19160701-V11-03.pdf',
#  'LibM19070101-V02-01.pdf',
#  'LibM19120401-V07-02.pdf',
#  'LibM19121001-V07-04.pdf',
#  'LibM19140401-V09-02.pdf',
#  'LibM19141001-V09-04.pdf',
#  'LibM19110701-V06-03.pdf',
#  'LibM19150101-V10-01.pdf',
#  'LibM19150701-V10-03.pdf',
#  'LibM19110101-V06-01.pdf',
#  'LibM19180401-V13-02.pdf',
#  'LibM19181001-V13-04.pdf',
#  'LibM19160401-V11-02.pdf',
#  'LibM19161001-V11-04.pdf',
#  'LibM19070701-V02-03.pdf',
#  'LibM19090701-V04-03.pdf',
#  'LibM19061001-V01-03.pdf',
#  'LibM19101001-V05-04.pdf',
#  'LibM19100401-V05-02.pdf',
#  'LibM19191001-V15-04.pdf',
#  'LibM19190401-V15-02.pdf',
#  'LibM19201001-V14-04.pdf',
#  'LibM19200401-V14-02.pdf',
#  'LibM19130701-V08-03.pdf',
#  'LibM19170101-V12-01.pdf',
#  'LibM19170701-V12-03.pdf',
#  'LibM19130101-V08-01.pdf',
#  'LibM19090101-V04-01.pdf',
#  'LibM19081001-V03-04.pdf',
#  'LibM19080401-V03-02.pdf',
#  'LibM19060401-V01-01.pdf']

# %%
periodical_list = os.listdir(sources_dir)

# %%
periodical_list
# Out:
# ['LibM19090401-V04-02.pdf',
#  'LibM19091001-V04-04.pdf',
#  'LibM19100701-V05-03.pdf',
#  'LibM19200701-V14-03.pdf',
#  'LibM19080101-V03-01.pdf',
#  'LibM19190701-V15-03.pdf',
#  'LibM19131001-V08-04.pdf',
#  'LibM19130401-V08-02.pdf',
#  'LibM19060701-V01-02.pdf',
#  'LibM19171001-V12-04.pdf',
#  'LibM19170401-V12-02.pdf',
#  'LibM19190101-V15-01.pdf',
#  'LibM19080701-V03-03.pdf',
#  'LibM19200101-V14-01.pdf',
#  'LibM19100101-V05-01.pdf',
#  'LibM19160401-V11-02e.pdf',
#  'LibM19160101-V11-01.pdf',
#  'LibM19120701-V07-03.pdf',
#  'LibM19140701-V09-03.pdf',
#  'LibM19160101-V11-01e.pdf',
#  'LibM19180101-V13-01.pdf',
#  'LibM19110401-V06-02.pdf',
#  'LibM19111001-V06-04.pdf',
#  'LibM19140101-V09-01.pdf',
#  'LibM19150401-V10-02.pdf',
#  'LibM19151001-V10-04.pdf',
#  'LibM19180701-V13-03.pdf',
#  'LibM19070401-V02-02.pdf',
#  'LibM19071001-V02-04.pdf',
#  'LibM19120101-V07-01.pdf',
#  'LibM19160701-V11-03.pdf',
#  'LibM19070101-V02-01.pdf',
#  'LibM19120401-V07-02.pdf',
#  'LibM19121001-V07-04.pdf',
#  'LibM19140401-V09-02.pdf',
#  'LibM19141001-V09-04.pdf',
#  'LibM19110701-V06-03.pdf',
#  'LibM19150101-V10-01.pdf',
#  'LibM19150701-V10-03.pdf',
#  'LibM19110101-V06-01.pdf',
#  'LibM19180401-V13-02.pdf',
#  'LibM19181001-V13-04.pdf',
#  'LibM19160401-V11-02.pdf',
#  'LibM19161001-V11-04.pdf',
#  'LibM19070701-V02-03.pdf',
#  'LibM19090701-V04-03.pdf',
#  'LibM19061001-V01-03.pdf',
#  'LibM19101001-V05-04.pdf',
#  'LibM19100401-V05-02.pdf',
#  'LibM19191001-V15-04.pdf',
#  'LibM19190401-V15-02.pdf',
#  'LibM19201001-V14-04.pdf',
#  'LibM19200401-V14-02.pdf',
#  'LibM19130701-V08-03.pdf',
#  'LibM19170101-V12-01.pdf',
#  'LibM19170701-V12-03.pdf',
#  'LibM19130101-V08-01.pdf',
#  'LibM19090101-V04-01.pdf',
#  'LibM19081001-V03-04.pdf',
#  'LibM19080401-V03-02.pdf',
#  'LibM19060401-V01-01.pdf']

# %% [markdown]
# What metadata is here?
# - Publication date (YYYYMMDD)
# - Volume Number
# - Issue Number
# - Periodical Title Key
#
# What can we use to split out the bits of info?
#
# - Dashes
#     split keydate | volume | issue
#
# How do we separate the date and title key?
# - regex to grab only letters
#
# How to separate YYYYMMDD?
#  first 4 (0-3) are year
#  4th and 5th positions are month
#  6th and 7th are day

# %%
import re
import csv

# %%
# [Periodical key, year, month, day, volume, issue]

with open('LibM-metadata.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(["periodical_key", "year", "month", "day", "volume", "issue"])

    for each in periodical_list:
        each = os.path.splitext(each)[0]
        first_split = each.split('-')
        print(first_split)
        title = re.match('[A-Za-z]*', first_split[0]).group(0)
        print(title)
        date = re.findall(r'\d+', first_split[0])[0]
        print(date)
        csvwriter.writerow([title, date[0:4], date[4:6], date[6:8], first_split[1], first_split[2]])
# Out:
# ['LibM19090401', 'V04', '02']
# LibM
# 19090401
# ['LibM19091001', 'V04', '04']
# LibM
# 19091001
# ['LibM19100701', 'V05', '03']
# LibM
# 19100701
# ['LibM19200701', 'V14', '03']
# LibM
# 19200701
# ['LibM19080101', 'V03', '01']
# LibM
# 19080101
# ['LibM19190701', 'V15', '03']
# LibM
# 19190701
# ['LibM19131001', 'V08', '04']
# LibM
# 19131001
# ['LibM19130401', 'V08', '02']
# LibM
# 19130401
# ['LibM19060701', 'V01', '02']
# LibM
# 19060701
# ['LibM19171001', 'V12', '04']
# LibM
# 19171001
# ['LibM19170401', 'V12', '02']
# LibM
# 19170401
# ['LibM19190101', 'V15', '01']
# LibM
# 19190101
# ['LibM19080701', 'V03', '03']
# LibM
# 19080701
# ['LibM19200101', 'V14', '01']
# LibM
# 19200101
# ['LibM19100101', 'V05', '01']
# LibM
# 19100101
# ['LibM19160401', 'V11', '02e']
# LibM
# 19160401
# ['LibM19160101', 'V11', '01']
# LibM
# 19160101
# ['LibM19120701', 'V07', '03']
# LibM
# 19120701
# ['LibM19140701', 'V09', '03']
# LibM
# 19140701
# ['LibM19160101', 'V11', '01e']
# LibM
# 19160101
# ['LibM19180101', 'V13', '01']
# LibM
# 19180101
# ['LibM19110401', 'V06', '02']
# LibM
# 19110401
# ['LibM19111001', 'V06', '04']
# LibM
# 19111001
# ['LibM19140101', 'V09', '01']
# LibM
# 19140101
# ['LibM19150401', 'V10', '02']
# LibM
# 19150401
# ['LibM19151001', 'V10', '04']
# LibM
# 19151001
# ['LibM19180701', 'V13', '03']
# LibM
# 19180701
# ['LibM19070401', 'V02', '02']
# LibM
# 19070401
# ['LibM19071001', 'V02', '04']
# LibM
# 19071001
# ['LibM19120101', 'V07', '01']
# LibM
# 19120101
# ['LibM19160701', 'V11', '03']
# LibM
# 19160701
# ['LibM19070101', 'V02', '01']
# LibM
# 19070101
# ['LibM19120401', 'V07', '02']
# LibM
# 19120401
# ['LibM19121001', 'V07', '04']
# LibM
# 19121001
# ['LibM19140401', 'V09', '02']
# LibM
# 19140401
# ['LibM19141001', 'V09', '04']
# LibM
# 19141001
# ['LibM19110701', 'V06', '03']
# LibM
# 19110701
# ['LibM19150101', 'V10', '01']
# LibM
# 19150101
# ['LibM19150701', 'V10', '03']
# LibM
# 19150701
# ['LibM19110101', 'V06', '01']
# LibM
# 19110101
# ['LibM19180401', 'V13', '02']
# LibM
# 19180401
# ['LibM19181001', 'V13', '04']
# LibM
# 19181001
# ['LibM19160401', 'V11', '02']
# LibM
# 19160401
# ['LibM19161001', 'V11', '04']
# LibM
# 19161001
# ['LibM19070701', 'V02', '03']
# LibM
# 19070701
# ['LibM19090701', 'V04', '03']
# LibM
# 19090701
# ['LibM19061001', 'V01', '03']
# LibM
# 19061001
# ['LibM19101001', 'V05', '04']
# LibM
# 19101001
# ['LibM19100401', 'V05', '02']
# LibM
# 19100401
# ['LibM19191001', 'V15', '04']
# LibM
# 19191001
# ['LibM19190401', 'V15', '02']
# LibM
# 19190401
# ['LibM19201001', 'V14', '04']
# LibM
# 19201001
# ['LibM19200401', 'V14', '02']
# LibM
# 19200401
# ['LibM19130701', 'V08', '03']
# LibM
# 19130701
# ['LibM19170101', 'V12', '01']
# LibM
# 19170101
# ['LibM19170701', 'V12', '03']
# LibM
# 19170701
# ['LibM19130101', 'V08', '01']
# LibM
# 19130101
# ['LibM19090101', 'V04', '01']
# LibM
# 19090101
# ['LibM19081001', 'V03', '04']
# LibM
# 19081001
# ['LibM19080401', 'V03', '02']
# LibM
# 19080401
# ['LibM19060401', 'V01', '01']
# LibM
# 19060401
