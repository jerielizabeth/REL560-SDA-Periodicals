# %%
periodical = "SOL"
sources_dir = "/Users/jacobbarrett/Documents/GitHub/REL560-SDA-Periodicals/Periodicals/{}".format(periodical)

# %%
sources_dir
# Out:
# '/Users/jacobbarrett/Documents/GitHub/REL560-SDA-Periodicals/Periodicals/SOL'

# %%
import os

# %%
os.listdir(sources_dir)
# Out:
# ['SOL19031001-V18-40.pdf',
#  'SOL19040107-V19-01.pdf',
#  'SOL19040121-V19-03.pdf',
#  'SOL19021101-V17-12.pdf',
#  'SOL19030924-V18-39.pdf',
#  'SOL19030319-V18-12.pdf',
#  'SOL19030528-V18-22.pdf',
#  'SOL19030910-V18-37.pdf',
#  'SOL19030723-V18-30.pdf',
#  'SOL19020301-V17-04.pdf',
#  'SOL19030611-V18-24.pdf',
#  'SOL19030305-V18-10.pdf',
#  'SOL19000816-V15-32.pdf',
#  'SOL19000726-V15-29.pdf',
#  'SOL19020201-V17-03.pdf',
#  'SOL19040204-V19-05.pdf',
#  'SOL19020401-V17-05.pdf',
#  'SOL19000802-V15-30.pdf',
#  'SOL19030423-V18-17.pdf',
#  'SOL19031224-V18-51.pdf',
#  'SOL19020501-V17-06.pdf',
#  'SOL19031015-V18-41.pdf',
#  'SOL19030205-V18-06.pdf',
#  'SOL19030326-V18-13.pdf',
#  'SOL19020701-V17-08.pdf',
#  'SOL19030827-V18-35.pdf',
#  'SOL19000913-V15-36.pdf',
#  'SOL19031022-V18-42.pdf',
#  'SOL19000927-V15-38.pdf',
#  'SOL19000628-V15-25.pdf',
#  'SOL19031210-V18-49.pdf',
#  'SOL19021001-V17-11.pdf',
#  'SOL19030820-V18-34.pdf',
#  'SOL19001108-V15-44.pdf',
#  'SOL19040114-V19-02.pdf',
#  'SOL19000510-V15-17.pdf',
#  'SOL19031112-V18-45.pdf',
#  'SOL19030122-V18-04.pdf',
#  'SOL19030709-V18-28.pdf',
#  'SOL19000823-V15-33.pdf',
#  'SOL19030402-V18-14.pdf',
#  'SOL19030101-V18-01.pdf',
#  'SOL19030730-V18-31.pdf',
#  'SOL19030903-V18-36.pdf',
#  'SOL19030115-V18-03.pdf',
#  'SOL19031203-V18-48.pdf',
#  'SOL19030416-V18-16.pdf',
#  'SOL19020901-V17-10.pdf',
#  'SOL19030702-V18-27.pdf',
#  'SOL19030806-V18-32.pdf',
#  'SOL19040211-V19-06.pdf',
#  'SOL19031105-V18-44.pdf',
#  'SOL19030129-V18-05.pdf',
#  'SOL19030521-V18-21.pdf',
#  'SOL19030409-V18-15.pdf',
#  'SOL19031119-V18-46.pdf',
#  'SOL19030430-V18-18.pdf',
#  'SOL19030618-V18-25.pdf',
#  'SOL19030917-V18-38.pdf',
#  'SOL19011201-V17-01.pdf',
#  'SOL19040128-V19-04.pdf',
#  'SOL19030604-V18-23.pdf',
#  'SOL19030507-V18-19.pdf',
#  'SOL19031231-V18-52.pdf',
#  'SOL19030716-V18-29.pdf',
#  'SOL19031217-V18-50.pdf',
#  'SOL19020801-V17-09.pdf',
#  'SOL19031126-V18-47.pdf',
#  'SOL19030219-V18-08.pdf',
#  'SOL19030108-V18-02.pdf',
#  'SOL19021201-V17-13.pdf',
#  'SOL19020101-V17-02.pdf',
#  'SOL19030514-V18-20.pdf',
#  'SOL19000517-V15-18.pdf',
#  'SOL19000614-V15-23.pdf',
#  'SOL19030312-V18-11.pdf',
#  'SOL19000809-V15-31.pdf',
#  'SOL19030625-V18-26.pdf',
#  'SOL19020601-V17-07.pdf',
#  'SOL19001101-V15-43.pdf',
#  'SOL19030226-V18-09.pdf',
#  'SOL19030212-V18-07.pdf',
#  'SOL19001005-V15-39.pdf',
#  'SOL19031029-V18-43.pdf',
#  'SOL19000531-V15-21.pdf',
#  'SOL19030813-V18-33.pdf']

# %%
periodical_list = os.listdir(sources_dir)

# %%
periodical_list
# Out:
# ['SOL19031001-V18-40.pdf',
#  'SOL19040107-V19-01.pdf',
#  'SOL19040121-V19-03.pdf',
#  'SOL19021101-V17-12.pdf',
#  'SOL19030924-V18-39.pdf',
#  'SOL19030319-V18-12.pdf',
#  'SOL19030528-V18-22.pdf',
#  'SOL19030910-V18-37.pdf',
#  'SOL19030723-V18-30.pdf',
#  'SOL19020301-V17-04.pdf',
#  'SOL19030611-V18-24.pdf',
#  'SOL19030305-V18-10.pdf',
#  'SOL19000816-V15-32.pdf',
#  'SOL19000726-V15-29.pdf',
#  'SOL19020201-V17-03.pdf',
#  'SOL19040204-V19-05.pdf',
#  'SOL19020401-V17-05.pdf',
#  'SOL19000802-V15-30.pdf',
#  'SOL19030423-V18-17.pdf',
#  'SOL19031224-V18-51.pdf',
#  'SOL19020501-V17-06.pdf',
#  'SOL19031015-V18-41.pdf',
#  'SOL19030205-V18-06.pdf',
#  'SOL19030326-V18-13.pdf',
#  'SOL19020701-V17-08.pdf',
#  'SOL19030827-V18-35.pdf',
#  'SOL19000913-V15-36.pdf',
#  'SOL19031022-V18-42.pdf',
#  'SOL19000927-V15-38.pdf',
#  'SOL19000628-V15-25.pdf',
#  'SOL19031210-V18-49.pdf',
#  'SOL19021001-V17-11.pdf',
#  'SOL19030820-V18-34.pdf',
#  'SOL19001108-V15-44.pdf',
#  'SOL19040114-V19-02.pdf',
#  'SOL19000510-V15-17.pdf',
#  'SOL19031112-V18-45.pdf',
#  'SOL19030122-V18-04.pdf',
#  'SOL19030709-V18-28.pdf',
#  'SOL19000823-V15-33.pdf',
#  'SOL19030402-V18-14.pdf',
#  'SOL19030101-V18-01.pdf',
#  'SOL19030730-V18-31.pdf',
#  'SOL19030903-V18-36.pdf',
#  'SOL19030115-V18-03.pdf',
#  'SOL19031203-V18-48.pdf',
#  'SOL19030416-V18-16.pdf',
#  'SOL19020901-V17-10.pdf',
#  'SOL19030702-V18-27.pdf',
#  'SOL19030806-V18-32.pdf',
#  'SOL19040211-V19-06.pdf',
#  'SOL19031105-V18-44.pdf',
#  'SOL19030129-V18-05.pdf',
#  'SOL19030521-V18-21.pdf',
#  'SOL19030409-V18-15.pdf',
#  'SOL19031119-V18-46.pdf',
#  'SOL19030430-V18-18.pdf',
#  'SOL19030618-V18-25.pdf',
#  'SOL19030917-V18-38.pdf',
#  'SOL19011201-V17-01.pdf',
#  'SOL19040128-V19-04.pdf',
#  'SOL19030604-V18-23.pdf',
#  'SOL19030507-V18-19.pdf',
#  'SOL19031231-V18-52.pdf',
#  'SOL19030716-V18-29.pdf',
#  'SOL19031217-V18-50.pdf',
#  'SOL19020801-V17-09.pdf',
#  'SOL19031126-V18-47.pdf',
#  'SOL19030219-V18-08.pdf',
#  'SOL19030108-V18-02.pdf',
#  'SOL19021201-V17-13.pdf',
#  'SOL19020101-V17-02.pdf',
#  'SOL19030514-V18-20.pdf',
#  'SOL19000517-V15-18.pdf',
#  'SOL19000614-V15-23.pdf',
#  'SOL19030312-V18-11.pdf',
#  'SOL19000809-V15-31.pdf',
#  'SOL19030625-V18-26.pdf',
#  'SOL19020601-V17-07.pdf',
#  'SOL19001101-V15-43.pdf',
#  'SOL19030226-V18-09.pdf',
#  'SOL19030212-V18-07.pdf',
#  'SOL19001005-V15-39.pdf',
#  'SOL19031029-V18-43.pdf',
#  'SOL19000531-V15-21.pdf',
#  'SOL19030813-V18-33.pdf']

# %% [markdown]
# What metadata is here?
# - Publication date (YYYYMMDD)
# - Volume Number
# - Issue Number
# - Periodical Title Key
#
# What can we use to split out the bits of info?
#
# - Dashes
#     split keydate | volume | issue
#
# How do we separate the date and title key?
# - regex to grab only letters
#
# How to separate YYYYMMDD?
#  first 4 (0-3) are year
#  4th and 5th positions are month
#  6th and 7th are day

# %%
import re
import csv

# %%
# [Periodical key, year, month, day, volume, issue]

with open('../Data/{}-metadata.csv'.format(periodical), 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(["file_name", "periodical_key", "year", "month", "day", "volume", "issue"])

    for each in periodical_list:
        each = os.path.splitext(each)[0]
        first_split = each.split('-')
        print(first_split)
        title = re.match('[A-Za-z]*', first_split[0]).group(0)
        print(title)
        date = re.findall(r'\d+', first_split[0])[0]
        print(date)
        csvwriter.writerow([each, title, date[0:4], date[4:6], date[6:8], first_split[1], first_split[2]])
# Out:
# ['SOL19031001', 'V18', '40']
# SOL
# 19031001
# ['SOL19040107', 'V19', '01']
# SOL
# 19040107
# ['SOL19040121', 'V19', '03']
# SOL
# 19040121
# ['SOL19021101', 'V17', '12']
# SOL
# 19021101
# ['SOL19030924', 'V18', '39']
# SOL
# 19030924
# ['SOL19030319', 'V18', '12']
# SOL
# 19030319
# ['SOL19030528', 'V18', '22']
# SOL
# 19030528
# ['SOL19030910', 'V18', '37']
# SOL
# 19030910
# ['SOL19030723', 'V18', '30']
# SOL
# 19030723
# ['SOL19020301', 'V17', '04']
# SOL
# 19020301
# ['SOL19030611', 'V18', '24']
# SOL
# 19030611
# ['SOL19030305', 'V18', '10']
# SOL
# 19030305
# ['SOL19000816', 'V15', '32']
# SOL
# 19000816
# ['SOL19000726', 'V15', '29']
# SOL
# 19000726
# ['SOL19020201', 'V17', '03']
# SOL
# 19020201
# ['SOL19040204', 'V19', '05']
# SOL
# 19040204
# ['SOL19020401', 'V17', '05']
# SOL
# 19020401
# ['SOL19000802', 'V15', '30']
# SOL
# 19000802
# ['SOL19030423', 'V18', '17']
# SOL
# 19030423
# ['SOL19031224', 'V18', '51']
# SOL
# 19031224
# ['SOL19020501', 'V17', '06']
# SOL
# 19020501
# ['SOL19031015', 'V18', '41']
# SOL
# 19031015
# ['SOL19030205', 'V18', '06']
# SOL
# 19030205
# ['SOL19030326', 'V18', '13']
# SOL
# 19030326
# ['SOL19020701', 'V17', '08']
# SOL
# 19020701
# ['SOL19030827', 'V18', '35']
# SOL
# 19030827
# ['SOL19000913', 'V15', '36']
# SOL
# 19000913
# ['SOL19031022', 'V18', '42']
# SOL
# 19031022
# ['SOL19000927', 'V15', '38']
# SOL
# 19000927
# ['SOL19000628', 'V15', '25']
# SOL
# 19000628
# ['SOL19031210', 'V18', '49']
# SOL
# 19031210
# ['SOL19021001', 'V17', '11']
# SOL
# 19021001
# ['SOL19030820', 'V18', '34']
# SOL
# 19030820
# ['SOL19001108', 'V15', '44']
# SOL
# 19001108
# ['SOL19040114', 'V19', '02']
# SOL
# 19040114
# ['SOL19000510', 'V15', '17']
# SOL
# 19000510
# ['SOL19031112', 'V18', '45']
# SOL
# 19031112
# ['SOL19030122', 'V18', '04']
# SOL
# 19030122
# ['SOL19030709', 'V18', '28']
# SOL
# 19030709
# ['SOL19000823', 'V15', '33']
# SOL
# 19000823
# ['SOL19030402', 'V18', '14']
# SOL
# 19030402
# ['SOL19030101', 'V18', '01']
# SOL
# 19030101
# ['SOL19030730', 'V18', '31']
# SOL
# 19030730
# ['SOL19030903', 'V18', '36']
# SOL
# 19030903
# ['SOL19030115', 'V18', '03']
# SOL
# 19030115
# ['SOL19031203', 'V18', '48']
# SOL
# 19031203
# ['SOL19030416', 'V18', '16']
# SOL
# 19030416
# ['SOL19020901', 'V17', '10']
# SOL
# 19020901
# ['SOL19030702', 'V18', '27']
# SOL
# 19030702
# ['SOL19030806', 'V18', '32']
# SOL
# 19030806
# ['SOL19040211', 'V19', '06']
# SOL
# 19040211
# ['SOL19031105', 'V18', '44']
# SOL
# 19031105
# ['SOL19030129', 'V18', '05']
# SOL
# 19030129
# ['SOL19030521', 'V18', '21']
# SOL
# 19030521
# ['SOL19030409', 'V18', '15']
# SOL
# 19030409
# ['SOL19031119', 'V18', '46']
# SOL
# 19031119
# ['SOL19030430', 'V18', '18']
# SOL
# 19030430
# ['SOL19030618', 'V18', '25']
# SOL
# 19030618
# ['SOL19030917', 'V18', '38']
# SOL
# 19030917
# ['SOL19011201', 'V17', '01']
# SOL
# 19011201
# ['SOL19040128', 'V19', '04']
# SOL
# 19040128
# ['SOL19030604', 'V18', '23']
# SOL
# 19030604
# ['SOL19030507', 'V18', '19']
# SOL
# 19030507
# ['SOL19031231', 'V18', '52']
# SOL
# 19031231
# ['SOL19030716', 'V18', '29']
# SOL
# 19030716
# ['SOL19031217', 'V18', '50']
# SOL
# 19031217
# ['SOL19020801', 'V17', '09']
# SOL
# 19020801
# ['SOL19031126', 'V18', '47']
# SOL
# 19031126
# ['SOL19030219', 'V18', '08']
# SOL
# 19030219
# ['SOL19030108', 'V18', '02']
# SOL
# 19030108
# ['SOL19021201', 'V17', '13']
# SOL
# 19021201
# ['SOL19020101', 'V17', '02']
# SOL
# 19020101
# ['SOL19030514', 'V18', '20']
# SOL
# 19030514
# ['SOL19000517', 'V15', '18']
# SOL
# 19000517
# ['SOL19000614', 'V15', '23']
# SOL
# 19000614
# ['SOL19030312', 'V18', '11']
# SOL
# 19030312
# ['SOL19000809', 'V15', '31']
# SOL
# 19000809
# ['SOL19030625', 'V18', '26']
# SOL
# 19030625
# ['SOL19020601', 'V17', '07']
# SOL
# 19020601
# ['SOL19001101', 'V15', '43']
# SOL
# 19001101
# ['SOL19030226', 'V18', '09']
# SOL
# 19030226
# ['SOL19030212', 'V18', '07']
# SOL
# 19030212
# ['SOL19001005', 'V15', '39']
# SOL
# 19001005
# ['SOL19031029', 'V18', '43']
# SOL
# 19031029
# ['SOL19000531', 'V15', '21']
# SOL
# 19000531
# ['SOL19030813', 'V18', '33']
# SOL
# 19030813
